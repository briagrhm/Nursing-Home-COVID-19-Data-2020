# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# Read the data into a Pandas DataFrame
df = pd.read_csv("faclevel_2020.csv",low_memory=False)
# Get the sheet names.
df.head()
# Out:
#   Week Ending Federal Provider Number             Provider Name  \
# 0    05/24/20                  015009  BURNS NURSING HOME, INC.
# 1    05/31/20                  015009  BURNS NURSING HOME, INC.
# 2    06/07/20                  015009  BURNS NURSING HOME, INC.
# 3    06/14/20                  015009  BURNS NURSING HOME, INC.
# 4    06/21/20                  015009  BURNS NURSING HOME, INC.
#
#        Provider Address Provider City Provider State  Provider Zip Code  \
# 0  701 MONROE STREET NW  RUSSELLVILLE             AL              35653
# 1  701 MONROE STREET NW  RUSSELLVILLE             AL              35653
# 2  701 MONROE STREET NW  RUSSELLVILLE             AL              35653
# 3  701 MONROE STREET NW  RUSSELLVILLE             AL              35653
# 4  701 MONROE STREET NW  RUSSELLVILLE             AL              35653
#
#    Provider Phone Number    County Submitted Data  ...  \
# 0             2563324110  Franklin              Y  ...
# ...

# %%
# Drop the empty rows
df_drop=df.drop(df.columns[[23,24,25,26,27,28,29,30,31]], axis=1)
df_drop
# Out:
#        Week Ending Federal Provider Number             Provider Name  \
# 0         05/24/20                  015009  BURNS NURSING HOME, INC.
# 1         05/31/20                  015009  BURNS NURSING HOME, INC.
# 2         06/07/20                  015009  BURNS NURSING HOME, INC.
# 3         06/14/20                  015009  BURNS NURSING HOME, INC.
# 4         06/21/20                  015009  BURNS NURSING HOME, INC.
# ...            ...                     ...                       ...
# 491028    11/29/20                  686124     HARMONY HEALTH CENTER
# 491029    12/06/20                  686124     HARMONY HEALTH CENTER
# 491030    12/13/20                  686124     HARMONY HEALTH CENTER
# 491031    12/20/20                  686124     HARMONY HEALTH CENTER
# 491032    12/27/20                  686124     HARMONY HEALTH CENTER
#
#             Provider Address Provider City Provider State  Provider Zip Code  \
# ...

# %%
df_drop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 491033 entries, 0 to 491032
# Data columns (total 23 columns):
#  #   Column                                                                           Non-Null Count   Dtype
# ---  ------                                                                           --------------   -----
#  0   Week Ending                                                                      491033 non-null  object
#  1   Federal Provider Number                                                          491033 non-null  object
#  2   Provider Name                                                                    491033 non-null  object
#  3   Provider Address                                                                 491033 non-null  object
#  4   Provider City                                                                    491033 non-null  object
# ...

# %%
#Rename the long column Names 
df_rename = df_drop.rename(columns={'Residents Hospitalizations with Confirmed COVID-19':'Hospitalizations with Confirmed COVID 19 ','Residents Hospitalizations with Confirmed COVID-19 and Up to Date with Vaccines':'Hospitalizations Confirmed COVID 19 and Up to Date Vaccines'})

# %%
#Change data type for the date 
df_rename['Week Ending']= pd.to_datetime(df_rename['Week Ending'], format='%m/%d/%y')
df_rename['Week Ending'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 491033 entries, 0 to 491032
# Series name: Week Ending
# Non-Null Count   Dtype
# --------------   -----
# 491033 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 3.7 MB

# %%
#check for missing data 
df_rename.isnull().sum()
# Out:
# Week Ending                                                       0
# Federal Provider Number                                           0
# Provider Name                                                     0
# Provider Address                                                  0
# Provider City                                                     0
# Provider State                                                    0
# Provider Zip Code                                                 0
# Provider Phone Number                                             0
# County                                                            0
# Submitted Data                                                    0
# Passed Quality Assurance Check                                 6712
# Residents Weekly Confirmed COVID-19                            5146
# Residents Total Confirmed COVID-19                             5146
# Residents Weekly All Deaths                                    5146
# ...

# %%
#Drop the rows with missing data 
df_clean=df_rename.dropna()
df_clean.isnull().sum()
# Out:
# Week Ending                                                    0
# Federal Provider Number                                        0
# Provider Name                                                  0
# Provider Address                                               0
# Provider City                                                  0
# Provider State                                                 0
# Provider Zip Code                                              0
# Provider Phone Number                                          0
# County                                                         0
# Submitted Data                                                 0
# Passed Quality Assurance Check                                 0
# Residents Weekly Confirmed COVID-19                            0
# Residents Total Confirmed COVID-19                             0
# Residents Weekly All Deaths                                    0
# ...

# %%
# Resize the figure
plt.figure(figsize=(20, 6))
#Create the plot 
plt.plot(df_rename["Provider State"], df_rename["Residents Total COVID-19 Deaths"])
plt.xlabel("Provider States")
plt.ylabel("Residents Total COVID-19 Deaths")
plt.title("Nursing Home Resident Death By State 2020")
# Rotate x-axis labels for better visibility
plt.xticks(rotation=45)
plt.show()

# %%
# Resize the figure
plt.figure(figsize=(20, 6))
#Create the plot 
plt.bar(df_rename["Provider State"], df_rename["Residents Total COVID-19 Deaths"])
plt.xlabel("Provider States")
plt.ylabel("Residents Total COVID-19 Deaths")
plt.title("Nursing Home Resident Death By State 2020")
# Rotate x-axis labels for better visibility
plt.xticks(rotation=45)
plt.show()

# %%
#df_rename['Provider State'].unique()

# %%
#Provider_states = df_rename['Provider State'].tolist()
#Provider_states

# %%
#counts=df_rename['Submitted Data'].value_counts()
#counts

# %%
#Beds=df_rename['Total Number of Occupied Beds'].tolist()

# %%
#df_rename.head()

# %%
#df_rename.to_csv("faclevel2020c.csv")

# %%
#df.columns.str.strip().str.replace('\s+', '_')
